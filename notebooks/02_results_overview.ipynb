# %% [markdown]
# # EEG Motor Imagery Results Overview
#
# This notebook is a lightweight viewer for the exported report assets.
# It does not duplicate the experiment logic.

# %%
from pathlib import Path
from IPython.display import Image, display

PROJECT_ROOT = Path.cwd().resolve().parent
ASSET_ROOT = PROJECT_ROOT / "docs" / "assets"
ASSET_ROOT

# %% [markdown]
# ## Main Quantitative Figures

# %%
for relative_path in [
    "generated/within_subject_accuracy.png",
    "generated/loso_accuracy.png",
    "generated/transfer_repeated_accuracy.png",
]:
    display(Image(filename=str(ASSET_ROOT / relative_path)))

# %% [markdown]
# ## Representative EDA Figures

# %%
for relative_path in [
    "eda_subject_1/subject_1_sensorimotor_erds.png",
    "eda_subject_2/subject_2_sensorimotor_erds.png",
    "eda_subject_8/subject_8_sensorimotor_erds.png",
    "group_eda/grand_average_sensorimotor_erds.png",
    "eda_subject_1/subject_1_classical_patterns.png",
    "eda_subject_1/subject_1_riemann_3d.png",
    "eda_subject_1/subject_1_riemann_lda_distribution.png",
    "eda_subject_1/subject_1_csp_projection.png",
    "eda_subject_1/subject_1_csp_lda_distribution.png",
    "eda_subject_1/subject_1_eegnet_saliency_topomap.png",
]:
    display(Image(filename=str(ASSET_ROOT / relative_path)))
